# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-A01793506/blob/main/Modulo%203%20Segunda%20parte%20notas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ast import Return
#Python for DataScience
#Erick Najera Olivero
#Modulo 3 

#Funciones
#Built-in functions
A=[1,3,8,4,2,6,7,5]
len(A)  # funcion que arroja el tamaño de lista, set, tupla

sum(A)  #retorna la suma de los elementos de la lista

sorted(A)  #Ordena los valores de la lista
print(A)  # no cambia la lista

A.sort()
print(A) # esta funcion si cambia la lista

#Crear funciones propias



def funcion_nombre(a):
  """
  Recomendacion documentar las funciones con triple comillas para obetener descripcion con la funcion help.
  """
  if(a==1):
    return 'Erick'
  else:
    return "Najera"

funcion_nombre(0)     

help(funcion_nombre)

#Funcion con multiples parametros

def funcion_nombre2(a,b):
  """
  Funcion recibe dos parametros y devuelve el nombre de acuerdo a la sumatoria
  """
  if(a+b>10):
    return 'Erick'
  else:
    return 'Najera'  

funcion_nombre2(5,6) 

help(funcion_nombre2)


#loop dentro de funciones
nombres=['Erick','Pedro','Jose','Maria','Lina','Carlos']
def lista_nombres(nom):
  for i,n in enumerate(nom):
    print(n)

lista_nombres(nombres)


#Alcance de variables locales y globales

def fecha():
  fec=1990
  return fec

f=fecha()
print(f)

#print(fec)  # error porque la variable es local, no existe alcance global
# las varibles locales y globales con mismonombre no entran en conflicto

def fecha2():
  fec=1990
  return fec

f=fecha2()
fec=1950
print(f)
print(fec) #toma el valor global y no el asignado a la varible local

# %%
#What is the value of c after the following block of code is run ?

a=1

def add(b):

  return a+b

c=add(10)
c

#What is the value of c after the following block of code is run with proper numerical input?

def f(*x):
  return sum(x)

a=f(3,5,8)
a

# %%
#Objetos y clases
#Cada tipo de datos es representado como un objeto, es decir este es una instancia del tipo de dato
#Metdos son las clases o funciones que utlizamos para interactuar cob los objetos

#Creacion de clases
#Atributos de datos
#Metodos

#Creando una clase
#Clase para instanciar productos y valor del producto
class productos(object):
 def __init__(self,producto,precio):
    self.producto = producto;
    self.precio = precio;

    #agregamos metodos para cambiar valores de los datos
 def cambia_precio(self, nv):
    self.precio = nv  

#probando la clase
canasta1 = productos('Manzanas',5000)  
canasta1.precio
canasta1.cambia_precio(7000)  # probando metodo para cambiar precio
canasta1.precio

# %%
#Preguntas Review
x=1

if(x!=1):

 print('Hello')

else:

 print('Hi')

print('Mike')

#What is the output of the following few lines of code?

A = ['1','2','3']

for a in A:

 print(2*a)

 #Consider the function Delta, when will the function return a value of 1

def Delta(x):
 if x==0:
    y=1;
 else:
    y=0;
 return(y)

a=Delta(0)
print(a)
